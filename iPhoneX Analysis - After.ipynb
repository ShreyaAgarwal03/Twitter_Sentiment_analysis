# %%
import pandas as pd
import matplotlib.pyplot as plt
from nltk.stem import WordNetLemmatizer
from collections import Counter
import datetime
print 'Done'
# Out:
# Done

# %%
import json
import pandas

#Function to read Tweets
def readTweets(path):
    data = open(path)
    itemlist = []
    for line in data:
        item = json.loads(line)
        itemlist.append(item)
    return itemlist

def createDF(TweetList):
    df = pandas.DataFrame(data=TweetList)
    return df

def colTypeViewer(df):
    rowManager = 0
    for key in df.columns.values:
        print key, str(type(df[key][0]))
        rowManager+=1
        if rowManager == 2:
            rowManager = 0
            print('')

# %%
iPhoneTweets = createDF(readTweets('After - iPhoneX_Tweets.json'))

print('Dataset Dimensions:')
print('\tNumber of Keys (Columns): ' + str(iPhoneTweets.shape[0]))
print('\tNumber of Entries (Rows): ' + str(iPhoneTweets.shape[1]))
# Out:
# Dataset Dimensions:
# 	Number of Keys (Columns): 100010
# 	Number of Entries (Rows): 31

# %%
iPhoneTweets.head()
# Out:
#   contributors coordinates                      created_at  \
# 0         None        None  Sun Nov 05 03:26:03 +0000 2017
# 1         None        None  Sun Nov 05 03:26:03 +0000 2017
# 2         None        None  Sun Nov 05 03:26:02 +0000 2017
# 3         None        None  Sun Nov 05 03:26:02 +0000 2017
# 4         None        None  Sun Nov 05 03:26:02 +0000 2017
#
#                                             entities  \
# 0  {u'symbols': [], u'media': [{u'source_user_id'...
# 1  {u'symbols': [], u'media': [{u'source_user_id'...
# 2  {u'symbols': [], u'user_mentions': [], u'hasht...
# 3  {u'symbols': [], u'media': [{u'source_user_id'...
# 4  {u'symbols': [], u'media': [{u'source_user_id'...
#
#                                    extended_entities  favorite_count  \
# 0  {u'media': [{u'source_user_id': 164609710, u's...               0
# 1  {u'media': [{u'source_user_id': 164609710, u's...               0
# 2                                                NaN               0
# 3  {u'media': [{u'additional_media_info': {u'sour...               0
# 4  {u'media': [{u'source_user_id': 164609710, u's...               0
#
#    favorited   geo                  id              id_str  \
# 0      False  None  927014120133623809  927014120133623809
# 1      False  None  927014117570940928  927014117570940928
# 2      False  None  927014114165002240  927014114165002240
# 3      False  None  927014113330462720  927014113330462720
# 4      False  None  927014112302731266  927014112302731266
#
#            ...          quoted_status_id  quoted_status_id_str retweet_count  \
# 0          ...                       NaN                   NaN         22401
# 1          ...                       NaN                   NaN         22401
# 2          ...                       NaN                   NaN             0
# 3          ...                       NaN                   NaN          1203
# 4          ...                       NaN                   NaN         22401
#
#    retweeted                                   retweeted_status  \
# 0      False  {u'contributors': None, u'truncated': False, u...
# 1      False  {u'contributors': None, u'truncated': False, u...
# 2      False                                                NaN
# 3      False  {u'contributors': None, u'truncated': False, u...
# 4      False  {u'contributors': None, u'truncated': False, u...
#
#                                               source  \
# 0  <a href="http://twitter.com/download/iphone" r...
# 1  <a href="http://twitter.com/download/iphone" r...
# 2  <a href="http://mugen.tw" rel="nofollow">hoge2...
# 3  <a href="http://twitter.com/download/iphone" r...
# 4  <a href="http://twitter.com/download/iphone" r...
#
#                                                 text truncated  \
# 0      RT @guiruch: #iPhoneX https://t.co/wotnKabhMP     False
# 1      RT @guiruch: #iPhoneX https://t.co/wotnKabhMP     False
# 2  【悲報】iPhoneXでゲーム画面をスクショした結果…（画像あり） https://t.co...     False
# 3  RT @stalman: The #iPhoneX face mapping is so m...     False
# 4      RT @guiruch: #iPhoneX https://t.co/wotnKabhMP     False
#
#                                                 user withheld_in_countries
# 0  {u'follow_request_sent': None, u'has_extended_...                   NaN
# 1  {u'follow_request_sent': None, u'has_extended_...                   NaN
# 2  {u'follow_request_sent': None, u'has_extended_...                   NaN
# 3  {u'follow_request_sent': None, u'has_extended_...                   NaN
# 4  {u'follow_request_sent': None, u'has_extended_...                   NaN
#
# [5 rows x 31 columns]

# %%
# Extracting data from Tweet Dataset
tweetText = createDF(iPhoneTweets['text'])
#print('Rows: ' + str(tweetTimes.shape[0]))
#print('Columns: ' + str(tweetTimes.shape[1]))
tweetText.text.head(10)
# Out:
# 0        RT @guiruch: #iPhoneX https://t.co/wotnKabhMP
# 1        RT @guiruch: #iPhoneX https://t.co/wotnKabhMP
# 2    【悲報】iPhoneXでゲーム画面をスクショした結果…（画像あり） https://t.co...
# 3    RT @stalman: The #iPhoneX face mapping is so m...
# 4        RT @guiruch: #iPhoneX https://t.co/wotnKabhMP
# 5        RT @guiruch: #iPhoneX https://t.co/wotnKabhMP
# 6    RT @nanamorisan: ◆追加 \niphone4でiphoneXを釣る\n男心と...
# 7    iPhoneXの予約受付がついに開始しました。\n予約は下記URLから予約できます。\nht...
# 8        RT @guiruch: #iPhoneX https://t.co/wotnKabhMP
# 9    RT @manukasabakan: 嘘かホントかiPhoneXで持ち主が寝ている間に顔認証...
# Name: text, dtype: object

# %%
#python -m pip install wordcloud -in terminal
import nltk
from nltk.corpus import stopwords
valid_words = set(nltk.corpus.words.words())

def clean_tweet(data):
    cleaned_word = [x.encode('UTF8') for x in data] 
    cleaned_word = [x for x in cleaned_word if len(x)>1]
    cleaned_word = nltk.word_tokenize(str(cleaned_word))
    cleaned_word = [x for x in cleaned_word if x in valid_words]
    cleaned_word = [x for x in cleaned_word if x not in stopwords.words('english')]
    cleaned_word = [str.lower(i) for i in cleaned_word ]
    #print cleaned_word
    return cleaned_word

# %%
clean_tweet = clean_tweet(tweetText.text)
clean_df = createDF(clean_tweet)
clean_df.head()
# Out:
#            0
# 0        the
# 1       face
# 2       much
# 3  unlocking
# 4      phone

# %%
clean_df.to_csv('clean_tweet_words.csv', encoding='utf-8')
top_words  = createDF(clean_df.apply(lambda x: x.str.split(expand=True).stack()).stack().value_counts())
top_words = top_words.reset_index()
top_words.columns = ['word','count']
top_words.head()
# Out:
#     word  count
# 0    day  10336
# 1  waste  10020
# 2   half  10018
# 3  queen  10005
# 4      x   4971

# %%
top_df = top_words.sort_values('count', ascending=False)
top_df = top_df.head(15)
top_df
# Out:
#      word  count
# 0     day  10336
# 1   waste  10020
# 2    half  10018
# 3   queen  10005
# 4       x   4971
# 5     new   4007
# 6       i   3353
# 7      de   2431
# 8     the   2251
# 9      el   1831
# 10  phone   1643
# 11    get   1426
# 12   much   1410
# 13     la   1304
# 14   face   1296

# %%
import pandas as pd
import seaborn as sns

fig, ax = plt.subplots()
fig.set_size_inches(15, 5)
sns.barplot(x = 'word', y = 'count', data = top_df)
plt.show()
fig.savefig('top_words_after_launch.png')

# %%
bgs2 = nltk.bigrams(clean_tweet)

# compute frequency distribution for all the bigrams 
fdist2 = nltk.FreqDist(bgs2)

rslt2 = pd.DataFrame(Counter(fdist2).most_common(10),columns=['Word', 'Frequency'])
print('All frequencies, including STOPWORDS:')
print('=' * 60)
print(rslt2)
print('=' * 60)


fig, ax = plt.subplots()
fig.set_size_inches(15, 5)
sns.barplot(x = 'Word', y = 'Frequency', data = rslt2)
plt.xticks(rotation= 90)
plt.show()
fig.savefig('bigram_after_launch.png',bbox_inches = 'tight')
# Out:
# All frequencies, including STOPWORDS:
# ============================================================
#                  Word  Frequency
# 0         (half, day)      10007
# 1       (waste, half)      10003
# 2        (day, queen)      10000
# 3      (queen, waste)       3586
# 4  (unlocking, phone)       1016
# 5         (the, face)       1011
# 6   (much, unlocking)       1010
# 7        (face, much)       1010
# 8       (new, camera)        986
# 9      (new, already)        777
# ============================================================
